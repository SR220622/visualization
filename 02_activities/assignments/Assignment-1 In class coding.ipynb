# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize =(5,3))

#ax.scatter(x, y)
#ax.bar(x, y)
ax.plot(x, y)

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize =(5,3))

#ax.scatter(x, y)
#ax.bar(x, y)
#ax.plot(x, y)
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
plt.show()

# %%
font1 ={'family':'sans-serif','color':'blue', 'size':20}
font2 ={'family':'monospace','color':'green', 'size':14}


fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y)

ax.set_title('Total growth over time', fontdict= font1)
ax.set_ylabel('Total growth', fontdict= font2)
ax.set_xlabel('Years since start', fontdict= font2)
plt.show()

# %%
font1 ={'family':'sans-serif','color':'blue', 'size':20}
font2 ={'family':'monospace','color':'green', 'size':14}


fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y)

ax.set_title('Total growth over time', fontdict= font1, loc= 'right')
ax.set_ylabel('Total growth', fontdict= font2)
ax.set_xlabel('Years since start', fontdict= font2)
plt.show()

# %%
font1 ={'family':'sans-serif','color':'blue', 'size':20}
font2 ={'family':'monospace','color':'green', 'size':14}


fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y)

ax.set_title('Total growth over time', fontdict= font1, loc= 'left')
ax.set_ylabel('Total growth', fontdict= font2)
ax.set_xlabel('Years since start', fontdict= font2)
plt.show()

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.scatter(x, y,
           marker ='*',
           color = 'indigo')

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y,
           marker ='*',
           color = 'indigo',
           linestyle ='--',
           linewidth =2)

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y,
           marker ='*',
           color = 'indigo',
           linestyle ='--',
           linewidth =6)

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y,
           marker ='*',
           color = '#7425b9',
           linestyle ='--',
           linewidth =2,
           markersize =12,
           markeredgecolor = '#fa9359')

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y,
           marker ='*',
           color = '#7425b9',
           linestyle ='--',
           linewidth =2,
           markersize =12,
           markeredgecolor = '#fa9359',
           markerfacecolor ='black')


ax.grid()

# %%
fig, ax = plt.subplots(figsize =(5,3))
ax.plot(x, y,
        marker ='*',
        color = '#7425b9',
        linestyle ='--',
        linewidth =2,
        markersize =12,
        markeredgecolor = '#fa9359',
        markerfacecolor ='black')

ax.grid(axis ='y',
        color ='blue',
        linewiidth = 2,
        lifestyle ='dotted')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 11
#       1 fig, ax = plt.subplots(figsize =(5,3))
#       2 ax.plot(x, y,
#       3         marker ='*',
#       4         color = '#7425b9',
#    (...)
#       8         markeredgecolor = '#fa9359',
#       9         markerfacecolor ='black')
# ---> 11 ax.grid(axis ='y',
#      12         color ='blue',
#      13         linewiidth = 2,
#      14         lifestyle ='dotted')
#
# File c:\Users\samru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axes\_base.py:3276, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3274     self.xaxis.grid(visible, which=which, **kwargs)
#    3275 if axis in ['y', 'both']:
# -> 3276     self.yaxis.grid(visible, which=which, **kwargs)
#
# File c:\Users\samru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:1732, in Axis.grid(self, visible, which, **kwargs)
#    1729 if which in ['major', 'both']:
#    1730     gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1731                         if visible is None else visible)
# -> 1732     self.set_tick_params(which='major', **gridkw)
#    1733 self.stale = True
#
# File c:\Users\samru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:983, in Axis.set_tick_params(self, which, reset, **kwargs)
#     970 """
#     971 Set appearance parameters for ticks, ticklabels, and gridlines.
#     972
#    (...)
#     980     gridlines.
#     981 """
#     982 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 983 kwtrans = self._translate_tick_params(kwargs)
#     985 # the kwargs are stored in self._major/minor_tick_kw so that any
#     986 # future new ticks will automatically get them
#     987 if reset:
#
# File c:\Users\samru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:1127, in Axis._translate_tick_params(kw, reverse)
#    1125 for key in kw_:
#    1126     if key not in allowed_keys:
# -> 1127         raise ValueError(
#    1128             "keyword %s is not recognized; valid keywords are %s"
#    1129             % (key, allowed_keys))
#    1130 kwtrans.update(kw_)
#    1131 return kwtrans
#
# ValueError: keyword grid_linewiidth is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']
